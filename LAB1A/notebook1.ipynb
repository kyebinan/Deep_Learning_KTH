# %%
import numpy as np
import matplotlib.pyplot as plt

import datagen as dg 
import perceptron_rule as pr
import delta_rule as dr
from utils import visualize_loss_function

# %%
classA, classB = dg.generate_data()
dg.visualize_data(classA, classB)
classA.shape
# Out:
# (100, 2)

# %%
# shuffle the samples
data, label = dg.shuffle_data(classA, classB)
data.shape
# Out:
# (200, 2)

# %% [markdown]
# # Classification with a single-layer perceptron and analysis
#
# ### 1-Compare perceptron learning with the delta learning rule

# %%
epochs = 20
learning_rate = 0.002
# Applying perceptron learning online
W, B, errors = pr.perceptron_learning(data, label, epochs = epochs, learning_rate = learning_rate)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(classA[:, 0], classA[:, 1], color='red', label='Class 1')
plt.scatter(classB[:, 0], classB[:, 1], color='blue', label='Class -1')
x = np.array([np.min(data[:, 0]), np.max(data[:, 0])])
y = -(B[-1] + W[-1][0] * x)/W[-1][1]
plt.plot(x, y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'perceptron learning - Epoch {epochs}')
plt.legend()
plt.grid(True)
plt.show()

visualize_loss_function(errors=errors, title='perceptron learning - loss function')

# %%
epochs = 20
learning_rate = 0.001
# Applying perceptron learning online
W, errors = dr.delta_learning_online(data, label, epochs=epochs, learning_rate=learning_rate)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(classA[:, 0], classA[:, 1], color='red', label='Class 1')
plt.scatter(classB[:, 0], classB[:, 1], color='blue', label='Class -1')
x = np.array([np.min(data[:, 0]), np.max(data[:, 0])])
y = -(W[-1][2] + W[-1][0] * x)/W[-1][1]
plt.plot(x, y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'delta rule - Epoch {epochs}')
plt.legend()
plt.grid(True)
plt.show()

visualize_loss_function(errors=errors, title='delta rule - loss function')

# %% [markdown]
# ### 2- Compare sequential with a batch learning approach for the delta rule

# %%
epochs = 20
learning_rate = 0.01
# Applying perceptron learning batch mode
W, errors = dr.delta_learning_batch(data, label, epochs=epochs, learning_rate=learning_rate, batch_size=50)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(classA[:, 0], classA[:, 1], color='red', label='Class 1')
plt.scatter(classB[:, 0], classB[:, 1], color='blue', label='Class -1')
x = np.array([np.min(data[:, 0]), np.max(data[:, 0])])
y = -(W[-1][2] + W[-1][0] * x)/W[-1][1]
plt.plot(x, y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'delta rule batch - Epoch {epochs}')
plt.legend()
plt.grid(True)
plt.show()

visualize_loss_function(errors=errors, title='delta rule batch - loss function')

# %%
epochs = 20
learning_rate = 0.001
# Applying perceptron learning batch mode
W, errors = dr.delta_learning_batch(data, label, epochs=epochs, learning_rate=learning_rate, batch_size=50)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(classA[:, 0], classA[:, 1], color='red', label='Class 1')
plt.scatter(classB[:, 0], classB[:, 1], color='blue', label='Class -1')
x = np.array([np.min(data[:, 0]), np.max(data[:, 0])])
y = -(W[-1][2] + W[-1][0] * x)/W[-1][1]
plt.plot(x, y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'delta rule batch - Epoch {epochs}')
plt.legend()
plt.grid(True)
plt.show()

visualize_loss_function(errors=errors, title='delta rule batch - loss function')

# %% [markdown]
# ### Remove the bias, train your network with delta rule in batch mode and test behaviour

# %%
epochs = 20
learning_rate = 0.001
# Applying perceptron learning batch mode
W, errors = dr.delta_learning_batch_without_bias(data, label, epochs=epochs, learning_rate=learning_rate, batch_size=50)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(classA[:, 0], classA[:, 1], color='red', label='Class 1')
plt.scatter(classB[:, 0], classB[:, 1], color='blue', label='Class -1')
x = np.array([np.min(data[:, 0]), np.max(data[:, 0])])
y = -(W[-1][2] + W[-1][0] * x)/W[-1][1]
plt.plot(x, y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'delta rule batch - Epoch {epochs}')
plt.legend()
plt.grid(True)
plt.show()

visualize_loss_function(errors=errors, title='delta rule batch - loss function')

# %%
classA, classB = dg.generate_data(n=100, mA=np.array([1.0, 0.5]), sigmaA=0.1, mB=np.array([-1.0, 0.0]), sigmaB=0.15)
dg.visualize_data(classA, classB)
classA.shape
# Out:
# (100, 2)

# %%
# shuffle the samples
data, label = dg.shuffle_data(classA, classB)
data.shape
# Out:
# (200, 2)

# %%
epochs = 20
learning_rate = 0.01
# Applying perceptron learning batch mode
W, errors = dr.delta_learning_batch_without_bias(data, label, epochs=epochs, learning_rate=learning_rate, batch_size=50)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(classA[:, 0], classA[:, 1], color='red', label='Class 1')
plt.scatter(classB[:, 0], classB[:, 1], color='blue', label='Class -1')
x = np.array([np.min(data[:, 0]), np.max(data[:, 0])])
y = -(W[-1][2] + W[-1][0] * x)/W[-1][1]
plt.plot(x, y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'delta rule batch - Epoch {epochs}')
plt.legend()
plt.grid(True)
plt.show()

visualize_loss_function(errors=errors, title='delta rule batch - loss function')

# %% [markdown]
# # Classification of samples that are not linearly separable

# %%
classA, classB = dg.generate_data(n=100, mA=np.array([1.0, 0.3]), sigmaA=0.3, mB=np.array([0.0, -0.1]), sigmaB=0.3)
dg.visualize_data(classA, classB)
classA.shape
# Out:
# (100, 2)

# %%
# shuffle the samples
data, label = dg.shuffle_data(classA[:75,:], classB[:75,:])
data.shape
# Out:
# (150, 2)

# %%
epochs = 20
learning_rate = 0.01
# Applying perceptron learning batch mode
W, errors = dr.delta_learning_batch(data, label, epochs=epochs, learning_rate=learning_rate, batch_size=50)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(classA[:, 0], classA[:, 1], color='red', label='Class 1')
plt.scatter(classB[:, 0], classB[:, 1], color='blue', label='Class -1')
x = np.array([np.min(data[:, 0]), np.max(data[:, 0])])
y = -(W[-1][2] + W[-1][0] * x)/W[-1][1]
plt.plot(x, y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'delta rule batch - Epoch {epochs}')
plt.legend()
plt.grid(True)
plt.show()

visualize_loss_function(errors=errors, title='delta rule batch - loss function')

# %%
# shuffle the samples
data, label = dg.shuffle_data(classA[25:75,:], classB)
data.shape
# Out:
# (150, 2)

# %%
epochs = 20
learning_rate = 0.01
# Applying perceptron learning batch mode
W, errors = dr.delta_learning_batch(data, label, epochs=epochs, learning_rate=learning_rate, batch_size=50)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(classA[:, 0], classA[:, 1], color='red', label='Class 1')
plt.scatter(classB[:, 0], classB[:, 1], color='blue', label='Class -1')
x = np.array([np.min(data[:, 0]), np.max(data[:, 0])])
y = -(W[-1][2] + W[-1][0] * x)/W[-1][1]
plt.plot(x, y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'delta rule batch - Epoch {epochs}')
plt.legend()
plt.grid(True)
plt.show()

visualize_loss_function(errors=errors, title='delta rule batch - loss function')

# %%
# shuffle the samples
data, label = dg.shuffle_data(classA, classB[25:75,:])
data.shape

# %%
epochs = 20
learning_rate = 0.01
# Applying perceptron learning batch mode
W, errors = dr.delta_learning_batch(data, label, epochs=epochs, learning_rate=learning_rate, batch_size=50)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(classA[:, 0], classA[:, 1], color='red', label='Class 1')
plt.scatter(classB[:, 0], classB[:, 1], color='blue', label='Class -1')
x = np.array([np.min(data[:, 0]), np.max(data[:, 0])])
y = -(W[-1][2] + W[-1][0] * x)/W[-1][1]
plt.plot(x, y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'delta rule batch - Epoch {epochs}')
plt.legend()
plt.grid(True)
plt.show()

visualize_loss_function(errors=errors, title='delta rule batch - loss function')
